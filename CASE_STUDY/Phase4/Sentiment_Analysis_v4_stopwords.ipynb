# %% [markdown]
# # Sentiment Analysis and Stock Price Prediction

# %% [markdown]
# 1. Lexicon-based analysis is a straightforward approach to sentiment analysis, but it may not be as accurate as more complex methods.
# 2.
# Machine learning-based approaches can be more accurate, but they require labeled training data and may be more computationally expensive.
# 3.
# Pre-trained transformer-based deep learning approaches can achieve state-of-the-art accuracy but require significant computational resources and may not be practical for all use cas.

# %%
# import libraries
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
#reading the DJI
df=pd.read_csv('upload_DJIA_table.csv')
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0   82160000  17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %%
#Applying the logic to assign the Label
# 1 -> The close price of the next day has increased compared to previous close price
# 0 -> The close price of the next day has decreased/stayed the same compared to previous close price
df['Label'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# %%
#since the lastest data will not have next day data to compare, it's been removed
df['Label']=(df['Label'].shift(1))
df=df.dropna().reset_index(drop=True)
df['Label']=df['Label'].astype(int)

# %%
df.head(8) #display
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 1  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 2  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 3  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
# 4  2016-06-24  17946.630859  17946.630859  17356.339844  17400.750000
# 5  2016-06-23  17844.109375  18011.070312  17844.109375  18011.070312
# 6  2016-06-22  17832.669922  17920.160156  17770.359375  17780.830078
# 7  2016-06-21  17827.330078  17877.839844  17799.800781  17829.730469
#
#       Volume     Adj Close  Label
# 0  133030000  17929.990234      0
# 1  106380000  17694.679688      0
# 2  112190000  17409.720703      0
# 3  138740000  17140.240234      0
# 4  239000000  17400.750000      1
# 5   98070000  18011.070312      1
# 6   89440000  17780.830078      0
# 7   85130000  17829.730469      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1988 entries, 0 to 1987
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1988 non-null   object
#  1   Open       1988 non-null   float64
#  2   High       1988 non-null   float64
#  3   Low        1988 non-null   float64
#  4   Close      1988 non-null   float64
#  5   Volume     1988 non-null   int64
#  6   Adj Close  1988 non-null   float64
#  7   Label      1988 non-null   int32
# dtypes: float64(5), int32(1), int64(1), object(1)
# memory usage: 116.6+ KB

# %%
df['Date']=pd.to_datetime(df['Date']) #conver the Date into DateTime format

# %% [raw]
# The entries range from 2008-08-08 to 2016-06-29 and have total 1987 entries for DJI Data

# %% [markdown]
# # The Reddit News Dataset

# %% [markdown]
# ## Preprocessing the Data

# %%
# Read the dataset
df=pd.read_csv('RedditNews.csv')
df.head()
df['Date']=pd.to_datetime(df['Date'])
#df2['News'].astype(str)

# %%
# apply the function df
df['News'] = df['News'].apply(preprocess_text)
df
# Out:
#             Date                                               News
# 0     2016-07-01  117-year-old woman mexico city finally receive...
# 1     2016-07-01       imf chief back athens permanent olympic host
# 2     2016-07-01         president france say brexit , donald trump
# 3     2016-07-01  british man must give police 24 hour ' notice ...
# 4     2016-07-01  100+ nobel laureate urge greenpeace stop oppos...
# ...          ...                                                ...
# 73603 2008-06-08  b'man go berzerk akihabara stab everyone nearb...
# 73604 2008-06-08  b'threat world aid pandemic among heterosexual...
# 73605 2008-06-08  b'angst ankara : turkey steer dangerous identi...
# 73606 2008-06-08  b '' uk : identity card 'could used spy people...
# 73607 2008-06-08  b'marriage , said , reduced status commercial ...
#
# [73608 rows x 2 columns]

# %%
df.head(76)
# Out:
#          Date                                               News
# 0  2016-07-01  117-year-old woman mexico city finally receive...
# 1  2016-07-01       imf chief back athens permanent olympic host
# 2  2016-07-01         president france say brexit , donald trump
# 3  2016-07-01  british man must give police 24 hour ' notice ...
# 4  2016-07-01  100+ nobel laureate urge greenpeace stop oppos...
# ..        ...                                                ...
# 71 2016-06-29  google found disastrous symantec norton vulner...
# 72 2016-06-29  extremist violence rise germany : domestic int...
# 73 2016-06-29  bbc news : labour mp pas corbyn no-confidence ...
# 74 2016-06-29  tiny new zealand town 'too many job ' launch d...
# 75 2016-06-28  2,500 scientist australia : want save great ba...
#
# [76 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73608 entries, 0 to 73607
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    73608 non-null  datetime64[ns]
#  1   News    73608 non-null  object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Pivot Operation

# %% [markdown]
# There are top 25 news per day in the dataset one below the other, Need to change the dataset in such a way that there are unique rows according to date to apply the label

# %%
# we get the rank of the news in 25 - 25 series

# %%
df['rank']=df.groupby('Date').cumcount() + 1

# %%
df.head(26)
# Out:
#          Date                                               News  rank
# 0  2016-07-01  117-year-old woman mexico city finally receive...     1
# 1  2016-07-01       imf chief back athens permanent olympic host     2
# 2  2016-07-01         president france say brexit , donald trump     3
# 3  2016-07-01  british man must give police 24 hour ' notice ...     4
# 4  2016-07-01  100+ nobel laureate urge greenpeace stop oppos...     5
# 5  2016-07-01  brazil : huge spike number police killing rio ...     6
# 6  2016-07-01  austria 's highest court annuls presidential e...     7
# 7  2016-07-01  facebook win privacy case , track belgian want...     8
# 8  2016-07-01  switzerland denies muslim girl citizenship ref...     9
# 9  2016-07-01  china kill million innocent meditators organ ,...    10
# 10 2016-07-01  france crack factory farm - viral video campai...    11
# 11 2016-07-01  abbas plo faction call killer 13-year-old amer...    12
# 12 2016-07-01  taiwanese warship accidentally fire missile to...    13
# 13 2016-07-01  iran celebrates american human right week , mo...    14
# 14 2016-07-01  u.n. panel move curb bias l.g.b.t . people des...    15
# 15 2016-07-01  united state placed myanmar , uzbekistan , sud...    16
# 16 2016-07-01  & amp ; p revise european union credit rating ...    17
# 17 2016-07-01  india get $ 1 billion loan world bank solar mi...    18
# 18 2016-07-01  u.s. sailor detained iran spoke much interroga...    19
# 19 2016-07-01  mass fish kill vietnam solved taiwan steelmake...    20
# 20 2016-07-01  philippine president rodrigo duterte urge peop...    21
# 21 2016-07-01  spain arrest three pakistani accused promoting...    22
# 22 2016-07-01  venezuela , anger food shortage still mounting...    23
# 23 2016-07-01  hindu temple worker killed three men motorcycl...    24
# 24 2016-07-01  ozone layer hole seems healing - u & amp ; uk ...    25
# 25 2016-06-30  jamaica proposes marijuana dispenser tourist a...     1

# %%
# we pivot the table and bring all the news of rank 1-25 into one row hence there's only one unique corresponding date for neach series of news

# %%
pivot_df= df.pivot(index='Date', columns='rank', values='News').reset_index()

# %%
df2 = pivot_df # stored the

# %%
df2 = df2.dropna(axis=1) #in EDA it was observed that there were enties with more than 25 top news and hence there were more columns being created.
# dropped all the rows with NaN values to insure there is uniformity in data

# %% [markdown]
# we filter the data based on the available DJI index dataset dates inorder to apply the label

# %%
start_date=pd.to_datetime('2008-08-08')
end_date=pd.to_datetime('2016-06-29')

# %%
filtered_df= df2[(df2['Date'] >= start_date) & (df2['Date'] <= end_date)]

# %%
filtered_df.head()
# Out:
# rank       Date                                                  1  \
# 61   2008-08-08  b '' georgia 'downs two russian warplane ' cou...
# 62   2008-08-09           b'american killed chinese man olympics '
# 63   2008-08-10     b'spanish shopkeeper find homer simpson euro '
# 64   2008-08-11  b'why wont america nato help u ? wont help u ,...
# 65   2008-08-12  b'remember adorable 9-year-old sang opening ce...
#
# rank                                                  2  \
# 61                 b'breaking : musharraf impeached . '
# 62    b'russia v. georgia : oil & amp ; gas implicat...
# 63                    b'explosions rock western china '
# 64                  b'bush put foot georgian conflict '
# 65             b '' russia 'ends georgia operation ' ''
#
# rank                                                  3  \
# 61    b'russia today : column troop roll south osset...
# 62    b ' invisible hand turn beijing staging upside...
# 63    b'women egypt beginning feel conflicted regard...
# 64    b '' jewish georgian minister : thanks israeli...
# 65        b ' '' sexual harassment would child ... '' '
#
# rank                                                  4  \
# 61    b'russian tank moving towards capital south os...
# 62    b'russian fm : nato encouraged georgia - `` ne...
# 63    b'staged propoganda photo russia/georgia confl...
# 64    b'georgian army flees disarray russian advance...
# 65    b '' al-qa'eda losing support iraq brutal crac...
#
# rank                                                  5  \
# 61    b '' afghan child raped 'impunity , ' u.n. off...
# 62    b ' '' everyone hiding basement . one taking c...
# 63    b '' denmark 's energy independence -- 's done...
# 64    b '' olympic opening ceremony firework 'faked ...
# 65      b'ceasefire georgia : putin outmaneuvers west '
#
# rank                                                  6  \
# 61    b'150 russian tank entered south ossetia whils...
# 62                       b'38 dead bitten vampire bat '
# 63                    b'japan get serious immigration '
# 64    b'what mossad fraudulent new zealand passport ...
# 65    b'why microsoft intel tried kill xo $ 100 lapt...
#
# rank                                                  7  \
# 61    b '' breaking : georgia invades south ossetia ...
# 62     b '' georgia 's oil pipeline key u.s. support ''
# 63    b'as many 2,000 people may killed 30,000 made ...
# 64     b'russia angered israeli military sale georgia '
# 65      b'stratfor : russo-georgian war balance power '
#
# rank                                                  8  \
# 61    b '' 'enemy combatent ' trial nothing sham : s...
# 62    b '' mark almond : 's simplistic cast russia s...
# 63    b'breastfeeding mum fill vancouver h & amp ; s...
# 64    b'an american citizen living s.ossetia blame u...
# 65    b '' 'm trying get sense whole georgia-russia ...
#
# rank                                                  9  ...  \
# 61    b'georgian troop retreat s. osettain capital ,...  ...
# 62              b'georgia declares state war russia . '  ...
# 63    b'south ossetia conflict - `` probably confron...  ...
# 64         b'welcome world war iv ! high definition ! '  ...
# 65    b '' u military surprised timing swiftness rus...  ...
#
# rank                                                 13  \
# 61    b '' -- -russia georgia war nyt 's top story o...
# 62    b'georgia remove troop iraq fight breakaway so...
# 63    b'massive fire toronto propane depot force tho...
# 64         b ' u.s. ship head arctic define territory '
# 65    b'beginning war olympics opening violates anci...
#
# rank                                                 14  \
# 61        b '' china tell bush stay country ' affair ''
# 62    b '' german woman spends decade palma 's airpo...
# 63    b'russian troop advancing towards gori , invad...
# 64    b'drivers jerusalem taxi station threaten quit...
# 65    b'55 pyramid large luxor stacked mega-city pyr...
#
# rank                                                 15  \
# 61                  b'did world war iii start today ? '
# 62    b'bbc : iraqi militia disarm u set withdraw ti...
# 63    b '' georgia fall , europe 's hope energy inde...
# 64    b'the french team stunned phelps 4x100m relay ...
# 65                      b'the 11 top party city world '
#
# rank                                                 16  \
# 61    b'georgia invades south ossetia - russia get i...
# 62    b'israeli palestinian trade union reach histor...
# 63    b'though muslim , ahmed said saw difficulty wo...
# 64            b'israel u behind georgian aggression ? '
# 65    b ' u.s . troop still georgia ( know georgia f...
#
# rank                                                 17  \
# 61                  b'al-qaeda face islamist backlash '
# 62    b ' georgia parliament approves `` state war '' '
# 63            b '' russia 'prepares invade georgia ' ''
# 64    b ' '' believe tv , neither russian georgian ....
# 65                b'why russia response georgia right '
#
# rank                                                 18  \
# 61    b'condoleezza rice : `` u would act prevent is...
# 62    b ' 1,500 dead russian troop raid georgian town '
# 63      b'iraq demand `` clear '' u.s. troop timeline '
# 64    b'riots still going montreal ( canada ) police...
# 65    b'gorbachev accuses u.s. making `` serious blu...
#
# rank                                                 19  \
# 61    b'this busy day : european union approved new ...
# 62    b'bagpipes beijing : amazed amateur scottish b...
# 63             b'tring make sense georgia russian war '
# 64            b'china overtake u largest manufacturer '
# 65           b'russia , georgia , nato : cold war two '
#
# rank                                                 20  \
# 61    b '' georgia withdraw 1,000 soldier iraq help ...
# 62             b'olympic message beijing please leave '
# 63          b ' iraq demand clear u.s. troop timeline '
# 64                        b'war south ossetia [ pic ] '
# 65    b'remember adorable 62-year-old led country wa...
#
# rank                                                 21  \
# 61    b'why pentagon think attacking iran bad idea -...
# 62    b'freak czech train crash kill seven hitting c...
# 63      b'watch live tv covering russia/georgia war . '
# 64    b'israeli physician group condemns state tortu...
# 65                 b'war georgia : israeli connection '
#
# rank                                                 22
# 61    b'caucasus crisis : georgia invades south osse...
# 62    b'protests occur worldwide beijing olympics be...
# 63    b '' truth south ossetia war , georgia attack ...
# 64       b ' russia beaten united state head peak oil '
# 65    b'all sign point u encouraging georgia invade ...
#
# [5 rows x 23 columns]

# %%
filtered_df.columns = ['Date'] + [f'Top{i}' for i in range(1, 23)] #renamed the columns as top 25

# %%
filtered_df
# Out:
#            Date                                               Top1  \
# 61   2008-08-08  b '' georgia 'downs two russian warplane ' cou...
# 62   2008-08-09           b'american killed chinese man olympics '
# 63   2008-08-10     b'spanish shopkeeper find homer simpson euro '
# 64   2008-08-11  b'why wont america nato help u ? wont help u ,...
# 65   2008-08-12  b'remember adorable 9-year-old sang opening ce...
# ...         ...                                                ...
# 2936 2016-06-25  six week rio olympics , lab handling drug test...
# 2937 2016-06-26  authority raid 14 scientology office russia mo...
# 2938 2016-06-27    barclays rb share suspended trading tanking 8 %
# 2939 2016-06-28  2,500 scientist australia : want save great ba...
# 2940 2016-06-29                         explosion airport istanbul
#
#                                                    Top2  \
# 61                 b'breaking : musharraf impeached . '
# 62    b'russia v. georgia : oil & amp ; gas implicat...
# 63                    b'explosions rock western china '
# 64                  b'bush put foot georgian conflict '
# 65             b '' russia 'ends georgia operation ' ''
# ...                                                 ...
# 2936  global stock market lost $ 2 trillion value br...
# 2937  pope francis us term 'genocide ' describe arme...
# 2938  pope say church ask forgiveness gay past treat...
# 2939  personal detail 112,000 french police officer ...
# 2940  yemeni former president : terrorism offspring ...
#
#                                                    Top3  \
# 61    b'russia today : column troop roll south osset...
# 62    b ' invisible hand turn beijing staging upside...
# 63    b'women egypt beginning feel conflicted regard...
# 64    b '' jewish georgian minister : thanks israeli...
# 65        b ' '' sexual harassment would child ... '' '
# ...                                                 ...
# 2936  brexit : move canada trend u.k. european union...
# 2937  vladimir putin say brexit caused british polit...
# 2938         poland 'shocked ' xenophobic abuse pole uk
# 2939  & amp ; p cut united kingdom sovereign credit ...
# 2940   uk must accept freedom movement access eu market
#
#                                                    Top4  \
# 61    b'russian tank moving towards capital south os...
# 62    b'russian fm : nato encouraged georgia - `` ne...
# 63    b'staged propoganda photo russia/georgia confl...
# 64    b'georgian army flees disarray russian advance...
# 65    b '' al-qa'eda losing support iraq brutal crac...
# ...                                                 ...
# 2936  brexit : anger 'bregret ' leave voter say want...
# 2937        poll put support scottish independence 59 %
# 2938                 second referendum , cabinet agrees
# 2939                   huge helium deposit found africa
# 2940  devastated : scientist late captive breed mamm...
#
#                                                    Top5  \
# 61    b '' afghan child raped 'impunity , ' u.n. off...
# 62    b ' '' everyone hiding basement . one taking c...
# 63    b '' denmark 's energy independence -- 's done...
# 64    b '' olympic opening ceremony firework 'faked ...
# 65      b'ceasefire georgia : putin outmaneuvers west '
# ...                                                 ...
# 2936  petition second eu referendum reach 1,000,000 ...
# 2937  brexit : expat denied say eu referendum due mi...
# 2938         scotland welcome join eu , merkel ally say
# 2939  ceo south african state broadcaster quits shor...
# 2940  british labor party leader jeremy corbyn loses...
#
#                                                    Top6  \
# 61    b'150 russian tank entered south ossetia whils...
# 62                       b'38 dead bitten vampire bat '
# 63                    b'japan get serious immigration '
# 64    b'what mossad fraudulent new zealand passport ...
# 65    b'why microsoft intel tried kill xo $ 100 lapt...
# ...                                                 ...
# 2936  world 400 richest people lose $ 127 billion br...
# 2937  petition redo brexit referendum 3 million sign...
# 2938  sterling dip friday 's 31-year low amid brexit...
# 2939  brexit cost investor $ 2 trillion , worst one ...
# 2940            muslim shop uk firebombed people inside
#
#                                                    Top7  \
# 61    b '' breaking : georgia invades south ossetia ...
# 62     b '' georgia 's oil pipeline key u.s. support ''
# 63    b'as many 2,000 people may killed 30,000 made ...
# 64     b'russia angered israeli military sale georgia '
# 65      b'stratfor : russo-georgian war balance power '
# ...                                                 ...
# 2936  iceland voting presidential election historian...
# 2937  historian gudni johannesson claimed victory ic...
# 2938  negative news south african president allowed ...
# 2939  hong kong democracy activist call return briti...
# 2940    mexican authority sexually torture woman prison
#
#                                                    Top8  \
# 61    b '' 'enemy combatent ' trial nothing sham : s...
# 62    b '' mark almond : 's simplistic cast russia s...
# 63    b'breastfeeding mum fill vancouver h & amp ; s...
# 64    b'an american citizen living s.ossetia blame u...
# 65    b '' 'm trying get sense whole georgia-russia ...
# ...                                                 ...
# 2936  dozen bomb sniffing dog 'killed american secur...
# 2937  nigel farage said britain heading mild recessi...
# 2938   surge hate crime u.k. following u.k. brexit vote
# 2939  brexit : iceland president say uk join 'triang...
# 2940                    uk share pound continue recover
#
#                                                    Top9  ...  \
# 61    b'georgian troop retreat s. osettain capital ,...  ...
# 62              b'georgia declares state war russia . '  ...
# 63    b'south ossetia conflict - `` probably confron...  ...
# 64         b'welcome world war iv ! high definition ! '  ...
# 65    b '' u military surprised timing swiftness rus...  ...
# ...                                                 ...  ...
# 2936  thousand sign petition london become independe...  ...
# 2937                  iraq take 'last bastion falluja '  ...
# 2938  weapon shipped jordan cia saudi arabia intende...  ...
# 2939  uk 's osborne : 'absolutely ' going cut spendi...  ...
# 2940  iceland historian johannesson win presidential...  ...
#
#                                                   Top13  \
# 61    b '' -- -russia georgia war nyt 's top story o...
# 62    b'georgia remove troop iraq fight breakaway so...
# 63    b'massive fire toronto propane depot force tho...
# 64         b ' u.s. ship head arctic define territory '
# 65    b'beginning war olympics opening violates anci...
# ...                                                 ...
# 2936    election iceland today , 10 % population france
# 2937  uk food price set rise brexit vote - plunging ...
# 2938                  giant panda macau give birth twin
# 2939  `` ryanair deploy new aircraft route uk [ unit...
# 2940  former belgian prime minister ridicule nigel f...
#
#                                                   Top14  \
# 61        b '' china tell bush stay country ' affair ''
# 62    b '' german woman spends decade palma 's airpo...
# 63    b'russian troop advancing towards gori , invad...
# 64    b'drivers jerusalem taxi station threaten quit...
# 65    b'55 pyramid large luxor stacked mega-city pyr...
# ...                                                 ...
# 2936  scotland likely seek independence second time ...
# 2937  price increased 14,000 % -19,000 % four year v...
# 2938  get : eu leader tell britain must invoke artic...
# 2939  people , ever greedy stupid , destroy world - ...
# 2940  brexiteer nigel farage eu : 'you 're laughing ...
#
#                                                   Top15  \
# 61                  b'did world war iii start today ? '
# 62    b'bbc : iraqi militia disarm u set withdraw ti...
# 63    b '' georgia fall , europe 's hope energy inde...
# 64    b'the french team stunned phelps 4x100m relay ...
# 65                      b'the 11 top party city world '
# ...                                                 ...
# 2936  nigel farage admits 350m saving nh eu contribu...
# 2937  chance second referendum , say britain 's top ...
# 2938  sea turtle 'beaten left dead ' beach people ta...
# 2939  siemens freeze new uk wind power investment fo...
# 2940  islamic state bombing southern yemen kill 38 p...
#
#                                                   Top16  \
# 61    b'georgia invades south ossetia - russia get i...
# 62    b'israeli palestinian trade union reach histor...
# 63    b'though muslim , ahmed said saw difficulty wo...
# 64            b'israel u behind georgian aggression ? '
# 65    b ' u.s . troop still georgia ( know georgia f...
# ...                                                 ...
# 2936               london market lose $ 164b 600 second
# 2937  nicola sturgeon say scottish parliament could ...
# 2938      german lawyer probe erdogan alleged war crime
# 2939  u , canada mexico pledge 50 % power clean ener...
# 2940  escape tunnel , dug hand , found holocaust mas...
#
#                                                   Top17  \
# 61                  b'al-qaeda face islamist backlash '
# 62    b ' georgia parliament approves `` state war '' '
# 63            b '' russia 'prepares invade georgia ' ''
# 64    b ' '' believe tv , neither russian georgian ....
# 65                b'why russia response georgia right '
# ...                                                 ...
# 2936  cornwall vote brexit n't want lose million eu ...
# 2937  labour mp david lammy called parliament `` sto...
# 2938  boris johnson say uk continue `` intensify '' ...
# 2939  increasing evidence australia torturing refuge...
# 2940  land beijing sinking much four inch per year o...
#
#                                                   Top18  \
# 61    b'condoleezza rice : `` u would act prevent is...
# 62    b ' 1,500 dead russian troop raid georgian town '
# 63      b'iraq demand `` clear '' u.s. troop timeline '
# 64    b'riots still going montreal ( canada ) police...
# 65    b'gorbachev accuses u.s. making `` serious blu...
# ...                                                 ...
# 2936  pope francis describes mass killing armenian t...
# 2937  peru 's state energy company reported oil spil...
# 2938  richard branson calling uk government hold sec...
# 2939  richard branson , founder virgin group , said ...
# 2940  car bomb anti-islamic attack mosque perth , au...
#
#                                                   Top19  \
# 61    b'this busy day : european union approved new ...
# 62    b'bagpipes beijing : amazed amateur scottish b...
# 63             b'tring make sense georgia russian war '
# 64            b'china overtake u largest manufacturer '
# 65           b'russia , georgia , nato : cold war two '
# ...                                                 ...
# 2936  german foreign minister urge eu 'go looking re...
# 2937    hsbc 'to move job paris uk leaf single market '
# 2938                turkey 'sorry downing russian jet '
# 2939  37,000-yr-old skull borneo reveals surprise sc...
# 2940  emaciated lion taiz zoo trapped blood-soaked c...
#
#                                                   Top20  \
# 61    b '' georgia withdraw 1,000 soldier iraq help ...
# 62             b'olympic message beijing please leave '
# 63          b ' iraq demand clear u.s. troop timeline '
# 64                        b'war south ossetia [ pic ] '
# 65    b'remember adorable 62-year-old led country wa...
# ...                                                 ...
# 2936         thousand rally australia same-sex marriage
# 2937  coral reef plea letter sent prime minister aus...
# 2938    edward snowden lawyer vow new push pardon obama
# 2939  palestinian stone western wall worshiper ; pol...
# 2940  rupert murdoch describes brexit 'wonderful ' ....
#
#                                                   Top21  \
# 61    b'why pentagon think attacking iran bad idea -...
# 62    b'freak czech train crash kill seven hitting c...
# 63      b'watch live tv covering russia/georgia war . '
# 64    b'israeli physician group condemns state tortu...
# 65                 b'war georgia : israeli connection '
# ...                                                 ...
# 2936        cornwall vote brexit pleads keep eu funding
# 2937  post office northern ireland report 'unusually...
# 2938  brexit opinion poll reveals majority n't want ...
# 2939                jean-claude juncker asks farage : ?
# 2940                     40 killed yemen suicide attack
#
#                                                   Top22
# 61    b'caucasus crisis : georgia invades south osse...
# 62    b'protests occur worldwide beijing olympics be...
# 63    b '' truth south ossetia war , georgia attack ...
# 64       b ' russia beaten united state head peak oil '
# 65    b'all sign point u encouraging georgia invade ...
# ...                                                 ...
# 2936  brexit : moody 's downgrade uk 's credit outlo...
# 2937  `` n't believe right carry british commissione...
# 2938  conservative mp leave campaigner : `` leave ca...
# 2939  `` romanian remainians '' offering new home 48...
# 2940  google found disastrous symantec norton vulner...
#
# [2880 rows x 23 columns]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2880 entries, 61 to 2940
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2880 non-null   datetime64[ns]
#  1   Top1    2880 non-null   object
#  2   Top2    2880 non-null   object
#  3   Top3    2880 non-null   object
#  4   Top4    2880 non-null   object
#  5   Top5    2880 non-null   object
#  6   Top6    2880 non-null   object
#  7   Top7    2880 non-null   object
#  8   Top8    2880 non-null   object
#  9   Top9    2880 non-null   object
#  10  Top10   2880 non-null   object
#  11  Top11   2880 non-null   object
#  12  Top12   2880 non-null   object
#  13  Top13   2880 non-null   object
#  14  Top14   2880 non-null   object
#  15  Top15   2880 non-null   object
#  16  Top16   2880 non-null   object
#  17  Top17   2880 non-null   object
#  18  Top18   2880 non-null   object
#  19  Top19   2880 non-null   object
#  20  Top20   2880 non-null   object
#  21  Top21   2880 non-null   object
#  22  Top22   2880 non-null   object
# dtypes: datetime64[ns](1), object(22)
# memory usage: 540.0+ KB

# %% [markdown]
# We join the News table and the DJI table based on Date and assign label to the News dataset

# %%
merged_df= filtered_df.merge(df[['Date', 'Label']], on='Date', how='left')

# %%
merged_df.head()
# Out:
#         Date                                               Top1  \
# 0 2008-08-08  b '' georgia 'downs two russian warplane ' cou...
# 1 2008-08-09           b'american killed chinese man olympics '
# 2 2008-08-10     b'spanish shopkeeper find homer simpson euro '
# 3 2008-08-11  b'why wont america nato help u ? wont help u ,...
# 4 2008-08-12  b'remember adorable 9-year-old sang opening ce...
#
#                                                 Top2  \
# 0               b'breaking : musharraf impeached . '
# 1  b'russia v. georgia : oil & amp ; gas implicat...
# 2                  b'explosions rock western china '
# 3                b'bush put foot georgian conflict '
# 4           b '' russia 'ends georgia operation ' ''
#
#                                                 Top3  \
# 0  b'russia today : column troop roll south osset...
# 1  b ' invisible hand turn beijing staging upside...
# 2  b'women egypt beginning feel conflicted regard...
# 3  b '' jewish georgian minister : thanks israeli...
# 4      b ' '' sexual harassment would child ... '' '
#
#                                                 Top4  \
# 0  b'russian tank moving towards capital south os...
# 1  b'russian fm : nato encouraged georgia - `` ne...
# 2  b'staged propoganda photo russia/georgia confl...
# 3  b'georgian army flees disarray russian advance...
# 4  b '' al-qa'eda losing support iraq brutal crac...
#
#                                                 Top5  \
# 0  b '' afghan child raped 'impunity , ' u.n. off...
# 1  b ' '' everyone hiding basement . one taking c...
# 2  b '' denmark 's energy independence -- 's done...
# 3  b '' olympic opening ceremony firework 'faked ...
# 4    b'ceasefire georgia : putin outmaneuvers west '
#
#                                                 Top6  \
# 0  b'150 russian tank entered south ossetia whils...
# 1                     b'38 dead bitten vampire bat '
# 2                  b'japan get serious immigration '
# 3  b'what mossad fraudulent new zealand passport ...
# 4  b'why microsoft intel tried kill xo $ 100 lapt...
#
#                                                 Top7  \
# 0  b '' breaking : georgia invades south ossetia ...
# 1   b '' georgia 's oil pipeline key u.s. support ''
# 2  b'as many 2,000 people may killed 30,000 made ...
# 3   b'russia angered israeli military sale georgia '
# 4    b'stratfor : russo-georgian war balance power '
#
#                                                 Top8  \
# 0  b '' 'enemy combatent ' trial nothing sham : s...
# 1  b '' mark almond : 's simplistic cast russia s...
# 2  b'breastfeeding mum fill vancouver h & amp ; s...
# 3  b'an american citizen living s.ossetia blame u...
# 4  b '' 'm trying get sense whole georgia-russia ...
#
#                                                 Top9  ...  \
# 0  b'georgian troop retreat s. osettain capital ,...  ...
# 1            b'georgia declares state war russia . '  ...
# 2  b'south ossetia conflict - `` probably confron...  ...
# 3       b'welcome world war iv ! high definition ! '  ...
# 4  b '' u military surprised timing swiftness rus...  ...
#
#                                                Top14  \
# 0      b '' china tell bush stay country ' affair ''
# 1  b '' german woman spends decade palma 's airpo...
# 2  b'russian troop advancing towards gori , invad...
# 3  b'drivers jerusalem taxi station threaten quit...
# 4  b'55 pyramid large luxor stacked mega-city pyr...
#
#                                                Top15  \
# 0                b'did world war iii start today ? '
# 1  b'bbc : iraqi militia disarm u set withdraw ti...
# 2  b '' georgia fall , europe 's hope energy inde...
# 3  b'the french team stunned phelps 4x100m relay ...
# 4                    b'the 11 top party city world '
#
#                                                Top16  \
# 0  b'georgia invades south ossetia - russia get i...
# 1  b'israeli palestinian trade union reach histor...
# 2  b'though muslim , ahmed said saw difficulty wo...
# 3          b'israel u behind georgian aggression ? '
# 4  b ' u.s . troop still georgia ( know georgia f...
#
#                                                Top17  \
# 0                b'al-qaeda face islamist backlash '
# 1  b ' georgia parliament approves `` state war '' '
# 2          b '' russia 'prepares invade georgia ' ''
# 3  b ' '' believe tv , neither russian georgian ....
# 4              b'why russia response georgia right '
#
#                                                Top18  \
# 0  b'condoleezza rice : `` u would act prevent is...
# 1  b ' 1,500 dead russian troop raid georgian town '
# 2    b'iraq demand `` clear '' u.s. troop timeline '
# 3  b'riots still going montreal ( canada ) police...
# 4  b'gorbachev accuses u.s. making `` serious blu...
#
#                                                Top19  \
# 0  b'this busy day : european union approved new ...
# 1  b'bagpipes beijing : amazed amateur scottish b...
# 2           b'tring make sense georgia russian war '
# 3          b'china overtake u largest manufacturer '
# 4         b'russia , georgia , nato : cold war two '
#
#                                                Top20  \
# 0  b '' georgia withdraw 1,000 soldier iraq help ...
# 1           b'olympic message beijing please leave '
# 2        b ' iraq demand clear u.s. troop timeline '
# 3                      b'war south ossetia [ pic ] '
# 4  b'remember adorable 62-year-old led country wa...
#
#                                                Top21  \
# 0  b'why pentagon think attacking iran bad idea -...
# 1  b'freak czech train crash kill seven hitting c...
# 2    b'watch live tv covering russia/georgia war . '
# 3  b'israeli physician group condemns state tortu...
# 4               b'war georgia : israeli connection '
#
#                                                Top22 Label
# 0  b'caucasus crisis : georgia invades south osse...   0.0
# 1  b'protests occur worldwide beijing olympics be...   NaN
# 2  b '' truth south ossetia war , georgia attack ...   NaN
# 3     b ' russia beaten united state head peak oil '   1.0
# 4  b'all sign point u encouraging georgia invade ...   1.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Since stock market is only open on Mon-Fri, the news data has Sat and sun news too, They don't have any labels assigned to them, hence we remove them

# %%
merged_df=merged_df.dropna().reset_index(drop=True)
merged_df['Label']=merged_df['Label'].astype(int)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1987 non-null   datetime64[ns]
#  1   Top1    1987 non-null   object
#  2   Top2    1987 non-null   object
#  3   Top3    1987 non-null   object
#  4   Top4    1987 non-null   object
#  5   Top5    1987 non-null   object
#  6   Top6    1987 non-null   object
#  7   Top7    1987 non-null   object
#  8   Top8    1987 non-null   object
#  9   Top9    1987 non-null   object
#  10  Top10   1987 non-null   object
#  11  Top11   1987 non-null   object
#  12  Top12   1987 non-null   object
#  13  Top13   1987 non-null   object
#  14  Top14   1987 non-null   object
#  15  Top15   1987 non-null   object
#  16  Top16   1987 non-null   object
#  17  Top17   1987 non-null   object
#  18  Top18   1987 non-null   object
#  19  Top19   1987 non-null   object
#  20  Top20   1987 non-null   object
#  21  Top21   1987 non-null   object
#  22  Top22   1987 non-null   object
#  23  Label   1987 non-null   int32
# dtypes: datetime64[ns](1), int32(1), object(22)
# memory usage: 364.9+ KB

# %%
df=merged_df #save the final Dataset in df

# %% [markdown]
# The final Cleaned Dataset is obtained with 22 Top news, A date and a Label Column

# %%
# df.to_csv('Final_DJI_News_Dataset.csv')#save the result

# %%
df
# Out:
#            Date                                               Top1  \
# 0    2008-08-08  b '' georgia 'downs two russian warplane ' cou...
# 1    2008-08-11  b'why wont america nato help u ? wont help u ,...
# 2    2008-08-12  b'remember adorable 9-year-old sang opening ce...
# 3    2008-08-13  b ' u.s. refuse israel weapon attack iran : re...
# 4    2008-08-14                 b'all expert admit legalise drug '
# ...         ...                                                ...
# 1982 2016-06-23  today united kingdom decides whether remain eu...
# 1983 2016-06-24              david cameron resign pm eu referendum
# 1984 2016-06-27    barclays rb share suspended trading tanking 8 %
# 1985 2016-06-28  2,500 scientist australia : want save great ba...
# 1986 2016-06-29                         explosion airport istanbul
#
#                                                    Top2  \
# 0                  b'breaking : musharraf impeached . '
# 1                   b'bush put foot georgian conflict '
# 2              b '' russia 'ends georgia operation ' ''
# 3     b '' president ordered attack tskhinvali [ cap...
# 4     b'war south osetia - 89 picture made russian s...
# ...                                                 ...
# 1982  e-cigarettes banned public , medical expert wa...
# 1983          bbc forecast uk vote leave european union
# 1984  pope say church ask forgiveness gay past treat...
# 1985  personal detail 112,000 french police officer ...
# 1986  yemeni former president : terrorism offspring ...
#
#                                                    Top3  \
# 0     b'russia today : column troop roll south osset...
# 1     b '' jewish georgian minister : thanks israeli...
# 2         b ' '' sexual harassment would child ... '' '
# 3     b ' israel clear troop killed reuters cameraman '
# 4     b'swedish wrestler ara abrahamian throw away m...
# ...                                                 ...
# 1982     report : china still harvesting organ prisoner
# 1983  nicola sturgeon say second independence refere...
# 1984         poland 'shocked ' xenophobic abuse pole uk
# 1985  & amp ; p cut united kingdom sovereign credit ...
# 1986   uk must accept freedom movement access eu market
#
#                                                    Top4  \
# 0     b'russian tank moving towards capital south os...
# 1     b'georgian army flees disarray russian advance...
# 2     b '' al-qa'eda losing support iraq brutal crac...
# 3     b'britain\ 's policy tough drug `` pointless '...
# 4     b'russia exaggerated death toll south ossetia ...
# ...                                                 ...
# 1982  man open fire cinema complex germany , several...
# 1983  's official . britain vote leave european union .
# 1984                 second referendum , cabinet agrees
# 1985                   huge helium deposit found africa
# 1986  devastated : scientist late captive breed mamm...
#
#                                                    Top5  \
# 0     b '' afghan child raped 'impunity , ' u.n. off...
# 1     b '' olympic opening ceremony firework 'faked ...
# 2       b'ceasefire georgia : putin outmaneuvers west '
# 3     b'body 14 year old found trunk ; latest ( rans...
# 4     b'missile killed 9 inside pakistan may launche...
# ...                                                 ...
# 1982               erdoan : europe , dont want u muslim
# 1983  world 's largest tibetan buddhist institute or...
# 1984         scotland welcome join eu , merkel ally say
# 1985  ceo south african state broadcaster quits shor...
# 1986  british labor party leader jeremy corbyn loses...
#
#                                                    Top6  \
# 0     b'150 russian tank entered south ossetia whils...
# 1     b'what mossad fraudulent new zealand passport ...
# 2     b'why microsoft intel tried kill xo $ 100 lapt...
# 3     b'china moved 10 * million * quake survivor pr...
# 4     b '' rushdie condemns random house 's refusal ...
# ...                                                 ...
# 1982  asian millionaire control wealth north america...
# 1983           single place scotland voted leave eu ...
# 1984  sterling dip friday 's 31-year low amid brexit...
# 1985  brexit cost investor $ 2 trillion , worst one ...
# 1986            muslim shop uk firebombed people inside
#
#                                                    Top7  \
# 0     b '' breaking : georgia invades south ossetia ...
# 1      b'russia angered israeli military sale georgia '
# 2       b'stratfor : russo-georgian war balance power '
# 3     b '' bush announces operation get russia 's gr...
# 4     b'poland u agree missle defense deal . interes...
# ...                                                 ...
# 1982  japanese porn industry association apologised ...
# 1983     rich getting richer expense poor , oxfam warns
# 1984  negative news south african president allowed ...
# 1985  hong kong democracy activist call return briti...
# 1986    mexican authority sexually torture woman prison
#
#                                                    Top8  \
# 0     b '' 'enemy combatent ' trial nothing sham : s...
# 1     b'an american citizen living s.ossetia blame u...
# 2     b '' 'm trying get sense whole georgia-russia ...
# 3                  b'russian force sink georgian ship '
# 4     b'will russian conquer tblisi ? bet , seriousl...
# ...                                                 ...
# 1982  university student warned class contains graph...
# 1983  spanish minister call gibraltar returned spain...
# 1984   surge hate crime u.k. following u.k. brexit vote
# 1985  brexit : iceland president say uk join 'triang...
# 1986                    uk share pound continue recover
#
#                                                    Top9  ...  \
# 0     b'georgian troop retreat s. osettain capital ,...  ...
# 1          b'welcome world war iv ! high definition ! '  ...
# 2     b '' u military surprised timing swiftness rus...  ...
# 3     b '' commander navy air reconnaissance squadro...  ...
# 4     b'russia exaggerating south ossetian death tol...  ...
# ...                                                 ...  ...
# 1982                afghan interpreter 'betrayed ' uk u  ...
# 1983  british pound drop nearly 5 % minute following...  ...
# 1984  weapon shipped jordan cia saudi arabia intende...  ...
# 1985  uk 's osborne : 'absolutely ' going cut spendi...  ...
# 1986  iceland historian johannesson win presidential...  ...
#
#                                                   Top14  \
# 0         b '' china tell bush stay country ' affair ''
# 1     b'drivers jerusalem taxi station threaten quit...
# 2     b'55 pyramid large luxor stacked mega-city pyr...
# 3     b'the cnn effect : georgia school russia infor...
# 4     b'the u poland agreed preliminary deal plan co...
# ...                                                 ...
# 1982  brexit supporter urged take pen polling statio...
# 1983  brexit : petition second eu referendum popular...
# 1984  get : eu leader tell britain must invoke artic...
# 1985  people , ever greedy stupid , destroy world - ...
# 1986  brexiteer nigel farage eu : 'you 're laughing ...
#
#                                                   Top15  \
# 0                   b'did world war iii start today ? '
# 1     b'the french team stunned phelps 4x100m relay ...
# 2                       b'the 11 top party city world '
# 3                 b'why russia response georgia right '
# 4     b'russia apparently sabotaging infrastructure ...
# ...                                                 ...
# 1982  city forge world 's largest alliance curb clim...
# 1983  north korea printing massive amount fake chine...
# 1984  sea turtle 'beaten left dead ' beach people ta...
# 1985  siemens freeze new uk wind power investment fo...
# 1986  islamic state bombing southern yemen kill 38 p...
#
#                                                   Top16  \
# 0     b'georgia invades south ossetia - russia get i...
# 1             b'israel u behind georgian aggression ? '
# 2     b ' u.s . troop still georgia ( know georgia f...
# 3                          b'elephants extinct 2020 ? '
# 4     b'bank analyst forecast georgian crisis 2 day ...
# ...                                                 ...
# 1982  colombia , farc announce full ceasefire , 'las...
# 1983  sinn fein call referendum irish reunification ...
# 1984      german lawyer probe erdogan alleged war crime
# 1985  u , canada mexico pledge 50 % power clean ener...
# 1986  escape tunnel , dug hand , found holocaust mas...
#
#                                                   Top17  \
# 0                   b'al-qaeda face islamist backlash '
# 1     b ' '' believe tv , neither russian georgian ....
# 2                 b'why russia response georgia right '
# 3     b'us humanitarian mission soon georgia - russi...
# 4     b '' georgia confict could set back russia 's ...
# ...                                                 ...
# 1982  gunman kill sufi devotional singer amjad sabri...
# 1983  $ 70 billion wiped australian sharemarket resu...
# 1984  boris johnson say uk continue `` intensify '' ...
# 1985  increasing evidence australia torturing refuge...
# 1986  land beijing sinking much four inch per year o...
#
#                                                   Top18  \
# 0     b'condoleezza rice : `` u would act prevent is...
# 1     b'riots still going montreal ( canada ) police...
# 2     b'gorbachev accuses u.s. making `` serious blu...
# 3                 b '' georgia 's ddos came u source ''
# 4     b'war caucasus much product american imperial ...
# ...                                                 ...
# 1982           india launch 20 satellite single mission
# 1983  nigel farage disowns vote leave '350m nh ' ple...
# 1984  richard branson calling uk government hold sec...
# 1985  richard branson , founder virgin group , said ...
# 1986  car bomb anti-islamic attack mosque perth , au...
#
#                                                   Top19  \
# 0     b'this busy day : european union approved new ...
# 1             b'china overtake u largest manufacturer '
# 2            b'russia , georgia , nato : cold war two '
# 3     b'russian convoy head georgia , violating truce '
# 4     b ' '' non-media '' photo south ossetia/georgi...
# ...                                                 ...
# 1982        f-16s manufactured soon assembly line india
# 1983         top eu leader : want britain soon possible
# 1984                turkey 'sorry downing russian jet '
# 1985  37,000-yr-old skull borneo reveals surprise sc...
# 1986  emaciated lion taiz zoo trapped blood-soaked c...
#
#                                                   Top20  \
# 0     b '' georgia withdraw 1,000 soldier iraq help ...
# 1                         b'war south ossetia [ pic ] '
# 2     b'remember adorable 62-year-old led country wa...
# 3          b'israeli defence minister : u strike iran '
# 4     b'georgian tv reporter shot russian sniper liv...
# ...                                                 ...
# 1982  australia 's gun law stopped mass shooting red...
# 1983  nigel farage : 350 million pledge fund nh 'big...
# 1984    edward snowden lawyer vow new push pardon obama
# 1985  palestinian stone western wall worshiper ; pol...
# 1986  rupert murdoch describes brexit 'wonderful ' ....
#
#                                                   Top21  \
# 0     b'why pentagon think attacking iran bad idea -...
# 1     b'israeli physician group condemns state tortu...
# 2                  b'war georgia : israeli connection '
# 3                                b'gorbachev : choice '
# 4     b'saudi arabia : mother move block child marri...
# ...                                                 ...
# 1982   french cement company syria buy oil isi document
# 1983    thousand london banking job cut start next week
# 1984  brexit opinion poll reveals majority n't want ...
# 1985                jean-claude juncker asks farage : ?
# 1986                     40 killed yemen suicide attack
#
#                                                   Top22 Label
# 0     b'caucasus crisis : georgia invades south osse...     0
# 1        b ' russia beaten united state head peak oil '     1
# 2     b'all sign point u encouraging georgia invade ...     1
# 3     b'witness : russian force head towards tbilisi...     0
# 4          b'taliban wage war humanitarian aid worker '     0
# ...                                                 ...   ...
# 1982  pope visit armenia irking turkey 'genocide ' l...     1
# 1983  google say large spike search irish passport a...     1
# 1984  conservative mp leave campaigner : `` leave ca...     0
# 1985  `` romanian remainians '' offering new home 48...     0
# 1986  google found disastrous symantec norton vulner...     0
#
# [1987 rows x 24 columns]

# %% [markdown]
# # Test -Train Split

# %% [markdown]
# we'll be doing a 70-30 train- test non ovelapping split of the data based on date

# %%
train = df[df['Date'] < '20140101']
test = df[df['Date'] > '20140101']

# %%
len(train) # 70%
# Out:
# 1359

# %%
len(test) #30%
# Out:
# 628

# %%
len(df)
# Out:
# 1987

# %% [markdown]
# We remove all non Alphabets characters from the feature columns

# %%
# Removing punctuations
data=train.iloc[:,1:23]
data.replace("[^a-zA-Z]"," ",regex=True, inplace=True) #remove verything except lowercase and uppercase a-z and replace it with blank space

# Renaming column names for ease of access (redundant step)
list1= [i for i in range(22)]
new_Index=[str(i) for i in list1]
data.columns= new_Index
data.head(5)
# Out:
#                                                    0  \
# 0  b    georgia  downs two russian warplane   cou...
# 1  b why wont america nato help u   wont help u  ...
# 2  b remember adorable   year old sang opening ce...
# 3  b   u s  refuse israel weapon attack iran   re...
# 4                 b all expert admit legalise drug
#
#                                                    1  \
# 0               b breaking   musharraf impeached
# 1                b bush put foot georgian conflict
# 2           b    russia  ends georgia operation
# 3  b    president ordered attack tskhinvali   cap...
# 4  b war south osetia      picture made russian s...
#
#                                                    2  \
# 0  b russia today   column troop roll south osset...
# 1  b    jewish georgian minister   thanks israeli...
# 2      b      sexual harassment would child
# 3  b   israel clear troop killed reuters cameraman
# 4  b swedish wrestler ara abrahamian throw away m...
#
#                                                    3  \
# 0  b russian tank moving towards capital south os...
# 1  b georgian army flees disarray russian advance...
# 2  b    al qa eda losing support iraq brutal crac...
# 3  b britain   s policy tough drug    pointless  ...
# 4  b russia exaggerated death toll south ossetia ...
#
#                                                    4  \
# 0  b    afghan child raped  impunity     u n  off...
# 1  b    olympic opening ceremony firework  faked ...
# 2    b ceasefire georgia   putin outmaneuvers west
# 3  b body    year old found trunk   latest   rans...
# 4  b missile killed   inside pakistan may launche...
#
#                                                    5  \
# 0  b     russian tank entered south ossetia whils...
# 1  b what mossad fraudulent new zealand passport ...
# 2  b why microsoft intel tried kill xo       lapt...
# 3  b china moved      million   quake survivor pr...
# 4  b    rushdie condemns random house  s refusal ...
#
#                                                    6  \
# 0  b    breaking   georgia invades south ossetia ...
# 1   b russia angered israeli military sale georgia
# 2    b stratfor   russo georgian war balance power
# 3  b    bush announces operation get russia  s gr...
# 4  b poland u agree missle defense deal   interes...
#
#                                                    7  \
# 0  b     enemy combatent   trial nothing sham   s...
# 1  b an american citizen living s ossetia blame u...
# 2  b     m trying get sense whole georgia russia ...
# 3               b russian force sink georgian ship
# 4  b will russian conquer tblisi   bet   seriousl...
#
#                                                    8  \
# 0  b georgian troop retreat s  osettain capital  ...
# 1       b welcome world war iv   high definition
# 2  b    u military surprised timing swiftness rus...
# 3  b    commander navy air reconnaissance squadro...
# 4  b russia exaggerating south ossetian death tol...
#
#                                                    9  ...  \
# 0             b did u s  prep georgia war russia      ...
# 1  b    georgia  s move   mistake monumental prop...  ...
# 2         b   u s   beat war drum iran dump dollar    ...
# 3  b         cnn reader   russia  s action georgi...  ...
# 4  b   musharraf expected resign rather face impe...  ...
#
#                                                   12  \
# 0  b        russia georgia war nyt  s top story o...
# 1       b   u s  ship head arctic define territory
# 2  b beginning war olympics opening violates anci...
# 3  b    intriguing cyberalliance   two estonian c...
# 4  b nigeria handed potentially oil rich bakassi ...
#
#                                                   13  \
# 0      b    china tell bush stay country   affair
# 1  b drivers jerusalem taxi station threaten quit...
# 2  b    pyramid large luxor stacked mega city pyr...
# 3  b the cnn effect   georgia school russia infor...
# 4  b the u poland agreed preliminary deal plan co...
#
#                                                   14  \
# 0                b did world war iii start today
# 1  b the french team stunned phelps  x   m relay ...
# 2                    b the    top party city world
# 3              b why russia response georgia right
# 4  b russia apparently sabotaging infrastructure ...
#
#                                                   15  \
# 0  b georgia invades south ossetia   russia get i...
# 1          b israel u behind georgian aggression
# 2  b   u s   troop still georgia   know georgia f...
# 3                       b elephants extinct
# 4  b bank analyst forecast georgian crisis   day ...
#
#                                                   16  \
# 0                b al qaeda face islamist backlash
# 1  b      believe tv   neither russian georgian  ...
# 2              b why russia response georgia right
# 3  b us humanitarian mission soon georgia   russi...
# 4  b    georgia confict could set back russia  s ...
#
#                                                   17  \
# 0  b condoleezza rice      u would act prevent is...
# 1  b riots still going montreal   canada   police...
# 2  b gorbachev accuses u s  making    serious blu...
# 3              b    georgia  s ddos came u source
# 4  b war caucasus much product american imperial ...
#
#                                                   18  \
# 0  b this busy day   european union approved new ...
# 1          b china overtake u largest manufacturer
# 2         b russia   georgia   nato   cold war two
# 3  b russian convoy head georgia   violating truce
# 4  b      non media    photo south ossetia georgi...
#
#                                                   19  \
# 0  b    georgia withdraw       soldier iraq help ...
# 1                      b war south ossetia   pic
# 2  b remember adorable    year old led country wa...
# 3       b israeli defence minister   u strike iran
# 4  b georgian tv reporter shot russian sniper liv...
#
#                                                   20  \
# 0  b why pentagon think attacking iran bad idea  ...
# 1  b israeli physician group condemns state tortu...
# 2               b war georgia   israeli connection
# 3                             b gorbachev   choice
# 4  b saudi arabia   mother move block child marri...
#
#                                                   21
# 0  b caucasus crisis   georgia invades south osse...
# 1     b   russia beaten united state head peak oil
# 2  b all sign point u encouraging georgia invade ...
# 3  b witness   russian force head towards tbilisi...
# 4       b taliban wage war humanitarian aid worker
#
# [5 rows x 22 columns]

# %% [markdown]
# Important to note that durning sentiment analysis, lowercase and uppercase words are treated as two seperate words and we don't want this to affect the accuracy of the model and hence we convert everything to lowercase

# %%
# Convertng headlines to lower case
for index in new_Index:
    data[index]=data[index].str.lower()
data.head(1)
# Out:
#                                                    0  \
# 0  b    georgia  downs two russian warplane   cou...
#
#                                       1  \
# 0  b breaking   musharraf impeached
#
#                                                    2  \
# 0  b russia today   column troop roll south osset...
#
#                                                    3  \
# 0  b russian tank moving towards capital south os...
#
#                                                    4  \
# 0  b    afghan child raped  impunity     u n  off...
#
#                                                    5  \
# 0  b     russian tank entered south ossetia whils...
#
#                                                    6  \
# 0  b    breaking   georgia invades south ossetia ...
#
#                                                    7  \
# 0  b     enemy combatent   trial nothing sham   s...
#
#                                                    8  \
# 0  b georgian troop retreat s  osettain capital  ...
#
#                                         9  ...  \
# 0  b did u s  prep georgia war russia      ...
#
#                                                   12  \
# 0  b        russia georgia war nyt  s top story o...
#
#                                               13  \
# 0  b    china tell bush stay country   affair
#
#                                     14  \
# 0  b did world war iii start today
#
#                                                   15  \
# 0  b georgia invades south ossetia   russia get i...
#
#                                     16  \
# 0  b al qaeda face islamist backlash
#
#                                                   17  \
# 0  b condoleezza rice      u would act prevent is...
#
#                                                   18  \
# 0  b this busy day   european union approved new ...
#
#                                                   19  \
# 0  b    georgia withdraw       soldier iraq help ...
#
#                                                   20  \
# 0  b why pentagon think attacking iran bad idea  ...
#
#                                                   21
# 0  b caucasus crisis   georgia invades south osse...
#
# [1 rows x 22 columns]

# %% [markdown]
# there are 22 differnt news for the saem day, need to concat them into a single para for training and testing our model

# %%
' '.join(str(x) for x in data.iloc[1,0:21])
# Out:
# 'b why wont america nato help u   wont help u   help iraq     b bush put foot georgian conflict   b    jewish georgian minister   thanks israeli training    re fending russia    b georgian army flees disarray russian advance   gori abandoned russia without shot fired   b    olympic opening ceremony firework  faked      b what mossad fraudulent new zealand passport iraq     b russia angered israeli military sale georgia   b an american citizen living s ossetia blame u s  georgian leader genocide innocent people   b welcome world war iv   high definition     b    georgia  s move   mistake monumental proportion    b russia press deeper georgia   u s  say regime change goal   b abhinav bindra win first ever individual olympic gold medal india   b   u s  ship head arctic define territory   b drivers jerusalem taxi station threaten quit rather work new bos   arab   b the french team stunned phelps  x   m relay team   b israel u behind georgian aggression     b      believe tv   neither russian georgian   much victim      b riots still going montreal   canada   police murdered boy saturday     b china overtake u largest manufacturer   b war south ossetia   pic     b israeli physician group condemns state torture  '

# %%
headlines = []
for row in range(0,len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row,0:21]))

# %%
headlines[0]
# Out:
# 'b    georgia  downs two russian warplane   country move brink war    b breaking   musharraf impeached     b russia today   column troop roll south ossetia   footage fighting   youtube     b russian tank moving towards capital south ossetia   reportedly completely destroyed georgian artillery fire   b    afghan child raped  impunity     u n  official say   sick   three year old raped nothing    b     russian tank entered south ossetia whilst georgia shoot two russian jet     b    breaking   georgia invades south ossetia   russia warned would intervene  s side    b     enemy combatent   trial nothing sham   salim haman sentenced       year   kept longer anyway feel like      b georgian troop retreat s  osettain capital   presumably leaving several hundred people killed     video     b did u s  prep georgia war russia     b rice give green light israel attack iran   say u s  veto israeli military ops   b announcing   class action lawsuit behalf american public fbi   b        russia georgia war nyt  s top story opening ceremony olympics   fucking disgrace yet proof decline journalism      b    china tell bush stay country   affair    b did world war iii start today     b georgia invades south ossetia   russia get involved   nato absorb georgia unleash full scale war     b al qaeda face islamist backlash   b condoleezza rice      u would act prevent israeli strike iran      israeli defense minister ehud barak      israel prepared uncompromising victory case military hostility        b this busy day   european union approved new sanction iran protest nuclear programme     b    georgia withdraw       soldier iraq help fight russian force georgia  s breakaway region south ossetia    b why pentagon think attacking iran bad idea   u news   amp   world report  '

# %%
# create preprocess_text function
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())
    # Remove stop words
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    # Join the tokens back into a string
    processed_text = ' '.join(lemmatized_tokens)
    return processed_text

# %%
# # apply the function df
# df['News'] = df['News'].apply(preprocess_text)
# df

# %%
# headline_no_stopword=[]
# for i in range(len(headlines)):
#     headline_no_stopword.append(preprocess_text(headlines[i]))

# %%
# len(headlines)

# %%
# headline_no_stopword[1358]

# %%
# headlines=headline_no_stopword

# %% [markdown]
# # 1. Bag of Words

# %% [markdown]
# #import the libraries

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
## implement BAG OF WORDS
countvector=CountVectorizer(ngram_range=(2,2))
traindataset=countvector.fit_transform(headlines)

# %% [markdown]
# # RandomForest Classifier using Bag of Words

# %%
# implement RandomForest Classifier
randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
randomclassifier.fit(traindataset,train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %% [markdown]
# Need to convert the test data also into paragraph format

# %%
## Predict for the Test Dataset
test_transform= []
for row in range(0,len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row,1:22]))
test_dataset = countvector.transform(test_transform)
predictions = randomclassifier.predict(test_dataset)

# %%
## Import library to check accuracy and plot confusion matrix
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Stock Decreased', 'Stock Increased'])
# Out:
# [[332   0]
#  [295   1]]
# 0.5302547770700637
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69       332
#            1       1.00      0.00      0.01       296
#
#     accuracy                           0.53       628
#    macro avg       0.76      0.50      0.35       628
# weighted avg       0.75      0.53      0.37       628
#
# Confusion matrix, without normalization

# %%
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Stock Decreased', 'Stock Increased'])
# Out:
# [[332   0]
#  [295   1]]
# 0.5302547770700637
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69       332
#            1       1.00      0.00      0.01       296
#
#     accuracy                           0.53       628
#    macro avg       0.76      0.50      0.35       628
# weighted avg       0.75      0.53      0.37       628
#
# Confusion matrix, without normalization

# %% [markdown]
# # MultinomialNB using Bag of Words

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()
nb.fit(traindataset,train['Label'])
# Out:
# MultinomialNB()

# %%
predictions = nb.predict(test_dataset)
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Stock Decreased', 'Stock Increased'])
# Out:
# [[220 112]
#  [186 110]]
# 0.5254777070063694
#               precision    recall  f1-score   support
#
#            0       0.54      0.66      0.60       332
#            1       0.50      0.37      0.42       296
#
#     accuracy                           0.53       628
#    macro avg       0.52      0.52      0.51       628
# weighted avg       0.52      0.53      0.52       628
#
# Confusion matrix, without normalization

# %% [markdown]
# # PassiveAggressiveClassifier using Bag of Words

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
pa = PassiveAggressiveClassifier()
pa.fit(traindataset,train['Label'])
# Out:
# PassiveAggressiveClassifier()

# %%
predictions = pa.predict(test_dataset)
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Stock Decreased', 'Stock Increased'])
# Out:
# [[255  77]
#  [209  87]]
# 0.5445859872611465
#               precision    recall  f1-score   support
#
#            0       0.55      0.77      0.64       332
#            1       0.53      0.29      0.38       296
#
#     accuracy                           0.54       628
#    macro avg       0.54      0.53      0.51       628
# weighted avg       0.54      0.54      0.52       628
#
# Confusion matrix, without normalization

# %% [markdown]
# # 2. Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#implement TF-IDF
tfvector=TfidfVectorizer(ngram_range=(2,3))
train_df=tfvector.fit_transform(headlines)

# %% [markdown]
# # RandomForest Classifier Using TF-IDF

# %%
# implement RandomForest Classifier
randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
randomclassifier.fit(train_df,train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
test_dataset = tfvector.transform(test_transform)
predictions = randomclassifier.predict(test_dataset)

# %%
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Stock Decreased', 'Stock Increased'])
# Out:
# [[324   8]
#  [291   5]]
# 0.5238853503184714
#               precision    recall  f1-score   support
#
#            0       0.53      0.98      0.68       332
#            1       0.38      0.02      0.03       296
#
#     accuracy                           0.52       628
#    macro avg       0.46      0.50      0.36       628
# weighted avg       0.46      0.52      0.38       628
#
# Confusion matrix, without normalization

# %% [markdown]
# # MultinomialNB Using TF-IDF

# %%
nb=MultinomialNB()
nb.fit(train_df,train['Label'])
# Out:
# MultinomialNB()

# %%
predictions = nb.predict(test_dataset)
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Stock Decreased', 'Stock Increased'])
# Out:
# [[332   0]
#  [296   0]]
# 0.5286624203821656
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69       332
#            1       0.00      0.00      0.00       296
#
#     accuracy                           0.53       628
#    macro avg       0.26      0.50      0.35       628
# weighted avg       0.28      0.53      0.37       628
#
# Confusion matrix, without normalization
# C:\Users\a745154\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\a745154\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\a745154\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # PassiveAggressiveClassifier using TF-IDF

# %%
pa = PassiveAggressiveClassifier()
pa.fit(train_df,train['Label'])
# Out:
# PassiveAggressiveClassifier()

# %%
predictions = pa.predict(test_dataset)
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
plot_confusion_matrix(matrix, classes=['Down', 'Up'])
# Out:
# [[276  56]
#  [237  59]]
# 0.5334394904458599
#               precision    recall  f1-score   support
#
#            0       0.54      0.83      0.65       332
#            1       0.51      0.20      0.29       296
#
#     accuracy                           0.53       628
#    macro avg       0.53      0.52      0.47       628
# weighted avg       0.53      0.53      0.48       628
#
# Confusion matrix, without normalization

# %% [markdown]
# # End of Code
