# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_stock_data(symbol, start_date, end_date):
    stock = yf.Ticker(symbol)
    data = stock.history(period="1d", start=start_date, end=end_date)
    selected_columns = ['Open', 'Close', 'High', 'Low', 'Volume']
    data = data[selected_columns]
    return data
start_date = "2008-08-08"
end_date = "2016-06-29"

# %%
symbol = "AAPL" 
AAPL_data = get_stock_data(symbol, start_date, end_date)

# %%
symbol="^GSPC"
SP_data = get_stock_data(symbol, start_date, end_date)

# %%
SP_data.to_csv('SP_DJI_Dataset_v2.csv')#save the result

# %%
SP_data
# Out:
#                                   Open        Close         High          Low  \
# Date
# 2008-08-07 00:00:00-04:00  1286.510010  1266.069946  1286.510010  1264.290039
# 2008-08-08 00:00:00-04:00  1266.290039  1296.319946  1297.849976  1262.109985
# 2008-08-11 00:00:00-04:00  1294.420044  1305.319946  1313.150024  1291.410034
# 2008-08-12 00:00:00-04:00  1304.790039  1289.589966  1304.790039  1285.640015
# 2008-08-13 00:00:00-04:00  1288.640015  1285.829956  1294.030029  1274.859985
# ...                                ...          ...          ...          ...
# 2016-06-23 00:00:00-04:00  2092.800049  2113.320068  2113.320068  2092.800049
# 2016-06-24 00:00:00-04:00  2103.810059  2037.410034  2103.810059  2032.569946
# 2016-06-27 00:00:00-04:00  2031.449951  2000.540039  2031.449951  1991.680054
# 2016-06-28 00:00:00-04:00  2006.670044  2036.089966  2036.089966  2006.670044
# 2016-06-29 00:00:00-04:00  2042.689941  2070.770020  2073.129883  2042.689941
#
#                                Volume
# Date
# 2008-08-07 00:00:00-04:00  5319380000
# 2008-08-08 00:00:00-04:00  4966810000
# 2008-08-11 00:00:00-04:00  5067310000
# 2008-08-12 00:00:00-04:00  4711290000
# 2008-08-13 00:00:00-04:00  4787600000
# ...                               ...
# 2016-06-23 00:00:00-04:00  3297940000
# 2016-06-24 00:00:00-04:00  7597450000
# 2016-06-27 00:00:00-04:00  5431220000
# 2016-06-28 00:00:00-04:00  4385810000
# 2016-06-29 00:00:00-04:00  4241740000
#
# [1988 rows x 5 columns]

# %%
# AAPL_data.to_csv('AAPL_DJI_Dataset.csv')#save the result

# %%
df=pd.read_csv('AAPL_DJI_Dataset.csv')
df.head()
# Out:
#                         Date      Open     Close      High       Low  \
# 0  2008-08-08 00:00:00-04:00  4.967279  5.139766  5.142798  4.963944
# 1  2008-08-11 00:00:00-04:00  5.155530  5.261326  5.350449  5.143404
# 2  2008-08-12 00:00:00-04:00  5.260114  5.357422  5.435026  5.259811
# 3  2008-08-13 00:00:00-04:00  5.395315  5.435329  5.456549  5.332262
# 4  2008-08-14 00:00:00-04:00  5.405925  5.435935  5.470190  5.391071
#
#       Volume
# 0  713997200
# 1  891304400
# 2  836278800
# 3  842346400
# 4  711300800

# %%
df['Date']=pd.to_datetime(df['Date'], utc=True)
df['Date'] = df['Date'].dt.date

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1986 non-null   datetime64[ns]
#  1   Open    1986 non-null   float64
#  2   Close   1986 non-null   float64
#  3   High    1986 non-null   float64
#  4   Low     1986 non-null   float64
#  5   Volume  1986 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 93.2 KB

# %%
df
# Out:
#            Date       Open      Close       High        Low     Volume
# 0    2008-08-08   4.967279   5.139766   5.142798   4.963944  713997200
# 1    2008-08-11   5.155530   5.261326   5.350449   5.143404  891304400
# 2    2008-08-12   5.260114   5.357422   5.435026   5.259811  836278800
# 3    2008-08-13   5.395315   5.435329   5.456549   5.332262  842346400
# 4    2008-08-14   5.405925   5.435935   5.470190   5.391071  711300800
# ...         ...        ...        ...        ...        ...        ...
# 1981 2016-06-22  22.188493  22.027122  22.336032  21.981015  116876400
# 1982 2016-06-23  22.117026  22.153910  22.197711  21.957960  128960800
# 1983 2016-06-24  21.418527  21.531487  21.821955  21.358589  301245600
# 1984 2016-06-27  21.439271  21.217962  21.450798  21.093476  181958400
# 1985 2016-06-28  21.416219  21.575283  21.591422  21.241016  161779600
#
# [1986 rows x 6 columns]

# %%
#visualisation

# %%
df.describe()  # Summary statistics
# Out:
#                                 Date         Open        Close         High  \
# count                           1986  1986.000000  1986.000000  1986.000000
# mean   2012-07-18 07:38:58.368580096    14.674204    14.667066    14.812579
# min              2008-08-08 00:00:00     2.406642     2.370567     2.485761
# 25%              2010-07-29 06:00:00     7.909118     7.907827     7.980736
# 50%              2012-07-17 12:00:00    14.047509    14.022499    14.170305
# 75%              2014-07-09 18:00:00    21.083584    21.081359    21.236094
# max              2016-06-28 00:00:00    30.248728    29.941345    30.266722
# std                              NaN     7.700380     7.694743     7.759628
#
#                Low        Volume
# count  1986.000000  1.986000e+03
# mean     14.518552  4.577068e+08
# min       2.370567  5.218560e+07
# 25%       7.810444  2.440366e+08
# 50%      13.915761  3.889382e+08
# 75%      20.887560  5.749919e+08
# max      29.683815  2.622057e+09
# std       7.632197  3.113060e+08

# %%
# Line plot of Closing Prices

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Close'], label='Closing Price', color='b')

plt.title('AAPL Closing Prices')

plt.xlabel('Date')

plt.ylabel('Price')

plt.legend()

plt.grid(True)

plt.show()

# %%
# Candlestick plot

fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(df['Date'], df['Close'], label='Closing Price', color='b')

ax.set_xlabel('Date')

ax.set_ylabel('Price')

ax.legend(loc="upper left")

ax2 = ax.twinx()

ax2.plot(df['Date'], df['Open'], label='Opening Price', color='r')

ax2.fill_between(df['Date'], df['Open'], df['Close'], where=df['Open'] > df['Close'], facecolor='r', alpha=0.5)

ax2.fill_between(df['Date'], df['Open'], df['Close'], where=df['Open'] <= df['Close'], facecolor='g', alpha=0.5)

ax2.set_ylabel('Price')

ax2.legend(loc="upper right")



plt.title('AAPL Candlestick Chart')

plt.show()

# %%
# Create a new DataFrame for daily returns

daily_returns = df['Close'].pct_change()



# Daily Returns Histogram

plt.figure(figsize=(12, 6))

sns.histplot(daily_returns.dropna(), bins=100, color='b')

plt.title('Daily Returns Histogram')

plt.xlabel('Daily Returns')

plt.ylabel('Frequency')

plt.show()
# Out:
# C:\Users\a745154\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\a745154\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Moving Averages

moving_averages = [20, 50, 200]  # Define moving average periods

plt.figure(figsize=(12, 6))

for ma in moving_averages:

    df[f'SMA{ma}'] = df['Close'].rolling(window=ma).mean()

plt.plot(df['Date'], df['Close'], label='Closing Price', color='b')

for ma in moving_averages:

    plt.plot(df['Date'], df[f'SMA{ma}'], label=f'SMA{ma}')

plt.title(f'{symbol} Closing Price and Moving Averages')

plt.xlabel('Date')

plt.ylabel('Price')

plt.legend()

plt.grid(True)

plt.show()

# %%
# Volume Analysis

plt.figure(figsize=(12, 6))

plt.bar(df['Date'], df['Volume'], color='b')

plt.title('AAPL Trading Volume')

plt.xlabel('Date')

plt.ylabel('Volume')

plt.grid(True)

plt.show()

# %%
# Volume Moving Average

volume_ma = 20

plt.figure(figsize=(12, 6))

df['Volume_MA'] = df['Volume'].rolling(window=volume_ma).mean()

plt.plot(df['Date'], df['Volume'], label='Volume', color='b')

plt.plot(df['Date'], df['Volume_MA'], label=f'Volume SMA{volume_ma}', color='r')

plt.title('AAPL Volume and Volume Moving Average')

plt.xlabel('Date')

plt.ylabel('Volume')

plt.legend()

plt.grid(True)

plt.show()

# %%
# News Data using API

# %%
# importing requests package
import requests	 

def NewsFromBBC():
	
	# BBC news api
	# following query parameters are used
	# source, sortBy and apiKey
	query_params = {
	"source": "bbc-news",
	"sortBy": "top",
	"apiKey": "eefc48c6082242858476eadd689b4051"
	}
	main_url = " https://newsapi.org/v1/articles"

	# fetching data in json format
	res = requests.get(main_url, params=query_params)
	open_bbc_page = res.json()

	# getting all articles in a string article
	article = open_bbc_page["articles"]

	# empty list which will 
	# contain all trending news
	results = []
	
	for ar in article:
		results.append(ar["title"])
		
	for i in range(len(results)):
		
		# printing all trending news
		print(i + 1, results[i])			 

# function call
NewsFromBBC()
# Out:
# 1 Shockwaves from Israel-Hamas war disrupt US politics
# 2 Did Iran support plan for attack on Israel?
# 3 At least nine Americans killed in Hamas attack on Israel
# 4 Newsom vetoes California's caste discrimination bill
# 5 Afghanistan earthquake: More than 1,000 dead as villagers dig for survivors
# 6 Afghanistan: UK special forces 'killed 9 people in their beds'
# 7 Coin hoard could be linked to 1692's Glencoe Massacre
# 8 Mbankolo landslides kill 30 in Cameroon capital Yaoundé
# 9 Who will actually vote for Robert F Kennedy Jr as an independent candidate?
# 10 After Kevin McCarthy's ousting, who might replace him as US House Speaker?

# %%
#predictive analysis

# %%
# Import necessary libraries

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential

from keras.layers import LSTM, Dense, Dropout

from keras.optimizers import Adam

from sklearn.metrics import mean_squared_error

from sklearn.metrics import mean_absolute_error

from sklearn.metrics import r2_score

# from keras.wrappers.scikit_learn import KerasRegressor

from sklearn.model_selection import GridSearchCV

from ta import add_all_ta_features

from ta.utils import dropna

# %%
data=df

# %%
# Load the AAPL stock data (you can obtain this data from various sources)

 

# Data Preprocessing

# Select features (X) and target (y)

X = data[['Open', 'High', 'Low']]

y = data['Close']

 

# Split the data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

 

# Train a Random Forest Regressor model

model = RandomForestRegressor(n_estimators=100, random_state=42)

model.fit(X_train, y_train)

 

# Make predictions on the test set

y_pred = model.predict(X_test)

 

# Calculate the Mean Squared Error to evaluate the model

mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")

 

# Visualize the predicted vs. actual stock prices

plt.figure(figsize=(24, 6))

plt.plot(data.index[-len(y_test):], y_test, label='Actual Close Price', color='blue')

plt.plot(data.index[-len(y_test):], y_pred, label='Predicted Close Price', color='red')

plt.xlabel('Date')

plt.ylabel('Close Price')

plt.legend()

plt.title('AAPL Stock Price Prediction')

plt.show()
# Out:
# Mean Squared Error: 0.02

# %%
# Data Preprocessing

data = data[['Open', 'High', 'Low', 'Close']]

 

# Normalize the data using Min-Max scaling

scaler = MinMaxScaler()

data_scaled = scaler.fit_transform(data)

 

# Define a function to prepare the data for the LSTM model

def prepare_data(data, look_back=1):

    X, y = [], []

    for i in range(len(data) - look_back):

        X.append(data[i:(i+look_back)])

        y.append(data[i+look_back, 3])  # Closing price

    return np.array(X), np.array(y)

 

look_back = 20  # Adjust this to your desired sequence length

 

X, y = prepare_data(data_scaled, look_back)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

 

# Create and train the LSTM model

model = Sequential()

model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))

model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

model.fit(X_train, y_train, epochs=50, batch_size=64)

 

# Make predictions on the test set

y_pred = model.predict(X_test)

 

# Inverse transform the scaled data to get real values

# y_test = scaler.inverse_transform(y_test, (1, -1)))

# y_pred = scaler.inverse_transform(y_pred)

 

# Calculate the Mean Squared Error to evaluate the model

mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error: {mse:.5f}")

 

# Visualize the predicted vs. actual stock prices

plt.figure(figsize=(12, 6))

plt.plot(y_test, label='Actual Close Price', color='blue')

plt.plot(y_pred, label='Predicted Close Price', color='red')

plt.xlabel('Time')

plt.ylabel('Close Price')

plt.legend()

plt.title('AAPL Stock Price Prediction with LSTM')

plt.show()
# Out:
# Epoch 1/50
# 22/22 [==============================] - 1s 8ms/step - loss: 0.0302
# Epoch 2/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 3/50
# 22/22 [==============================] - 0s 7ms/step - loss: 6.2850e-04
# Epoch 4/50
# 22/22 [==============================] - 0s 9ms/step - loss: 4.0674e-04
# Epoch 5/50
# 22/22 [==============================] - 0s 8ms/step - loss: 3.8984e-04
# Epoch 6/50
# 22/22 [==============================] - 0s 7ms/step - loss: 3.8279e-04
# Epoch 7/50
# 22/22 [==============================] - 0s 9ms/step - loss: 3.8165e-04
# Epoch 8/50
# 22/22 [==============================] - 0s 8ms/step - loss: 3.7396e-04
# Epoch 9/50
# 22/22 [==============================] - 0s 8ms/step - loss: 3.6718e-04
# Epoch 10/50
# 22/22 [==============================] - 0s 7ms/step - loss: 3.6737e-04
# Epoch 11/50
# 22/22 [==============================] - 0s 8ms/step - loss: 3.6304e-04
# Epoch 12/50
# 22/22 [==============================] - 0s 8ms/step - loss: 3.5966e-04
# Epoch 13/50
# Epoch 48/50
# 22/22 [==============================] - 0s 7ms/step - loss: 2.2793e-04
# Epoch 49/50
# 22/22 [==============================] - 0s 7ms/step - loss: 2.2355e-04
# Epoch 50/50
# 22/22 [==============================] - 0s 7ms/step - loss: 2.3490e-04
# 19/19 [==============================] - 0s 2ms/step
# Mean Squared Error: 0.00022

# %%
#forecasting using bLSTM

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0        5.139766
# 1        5.261326
# 2        5.357422
# 3        5.435329
# 4        5.435935
#           ...
# 1981    22.027122
# 1982    22.153910
# 1983    21.531487
# 1984    21.217962
# 1985    21.575283
# Name: Close, Length: 1986, dtype: float64

# %%
scaler=MinMaxScaler(feature_range=(0,1)) # lstm is data range sensitive

df1=scaler.fit_transform(np.array(df1).reshape(-1,1)) # so to provide the input to fit into the fit_transform

# %%
##splitting dataset into train and test split

 

training_size=int(len(df1)*0.70) # 65% of the total length is the training data

test_size=len(df1)-training_size # the rest is testing data

train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1] #

# %%
training_size,test_size # total size is 1258
# Out:
# (1390, 596)

# %%
import numpy
def create_dataset(dataset, time_step=1): # we have this method create_dataset where

    dataX, dataY = [], []
    
    for i in range(len(dataset)-time_step-1):
    
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100
        
        dataX.append(a)
        
        dataY.append(dataset[i + time_step, 0])
    
    return numpy.array(dataX), numpy.array(dataY)

# %%
time_step = 100

X_train, y_train = create_dataset(train_data, time_step)

X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1289, 100)
# (1289,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (495, 100)
# (495,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1) # we need to re shape of x train into 3 dimension to load it into LSTM

# %%
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1) #

# %%
### Create the Stacked LSTM model

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense

from tensorflow.keras.layers import LSTM

from keras.layers import Bidirectional

from random import random

from numpy import array

from numpy import cumsum

from keras.layers import TimeDistributed

from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()

model.add(Bidirectional(LSTM(100, activation='relu'), input_shape=(100,1)))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#Stacked LSTM
# model=Sequential() # we are using a sequential model

# model.add(LSTM(50,return_sequences=True,input_shape=(100,1))) # 1st layer,  inputs are x train shape which is 100 and 1

# model.add(LSTM(50,return_sequences=True)) # 2nd layer,

# model.add(LSTM(50)) # 3rd layer,

# model.add(Dense(1)) # 1 final output

# model.compile(loss='mean_squared_error',optimizer='adam') # compiling with the help of mean_sq_error and adam optimiser

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 200)               81600
#  al)
#
#  dense_6 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 81801 (319.54 KB)
# Trainable params: 81801 (319.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=30,
        verbose=1, mode='auto', restore_best_weights=True)

# %%
history1=model.fit(X_train,y_train,validation_data=(X_test,ytest),
        callbacks=[monitor],verbose=1,epochs=1000)
# Out:
# Epoch 1/1000
# 41/41 [==============================] - 4s 61ms/step - loss: 0.0238 - val_loss: 0.0085
# Epoch 2/1000
# 41/41 [==============================] - 2s 57ms/step - loss: 0.0013 - val_loss: 0.0081
# Epoch 3/1000
# 41/41 [==============================] - 2s 57ms/step - loss: 7.4717e-04 - val_loss: 0.0038
# Epoch 4/1000
# 41/41 [==============================] - 2s 58ms/step - loss: 5.8445e-04 - val_loss: 0.0040
# Epoch 5/1000
# 41/41 [==============================] - 2s 58ms/step - loss: 4.9357e-04 - val_loss: 0.0022
# Epoch 6/1000
# 41/41 [==============================] - 2s 59ms/step - loss: 4.0477e-04 - val_loss: 0.0028
# Epoch 7/1000
# 41/41 [==============================] - 2s 58ms/step - loss: 3.3258e-04 - val_loss: 0.0056
# Epoch 8/1000
# 41/41 [==============================] - 3s 63ms/step - loss: 3.2888e-04 - val_loss: 0.0020
# Epoch 9/1000
# 41/41 [==============================] - 3s 61ms/step - loss: 3.0501e-04 - val_loss: 0.0014
# Epoch 10/1000
# 41/41 [==============================] - 2s 60ms/step - loss: 2.5355e-04 - val_loss: 0.0014
# Epoch 11/1000
# 41/41 [==============================] - 2s 60ms/step - loss: 2.4181e-04 - val_loss: 0.0016
# Epoch 12/1000
# 41/41 [==============================] - 2s 60ms/step - loss: 2.9257e-04 - val_loss: 0.0018
# Epoch 13/1000
# 41/41 [==============================] - 3s 64ms/step - loss: 2.4322e-04 - val_loss: 0.0014
# Epoch 14/1000
# 41/41 [==============================] - 2s 60ms/step - loss: 2.2045e-04 - val_loss: 0.0019
# Epoch 15/1000
# 41/41 [==============================] - 2s 60ms/step - loss: 2.2031e-04 - val_loss: 0.0029
# Epoch 16/1000
# 41/41 [==============================] - 3s 62ms/step - loss: 2.0441e-04 - val_loss: 0.0013
# Epoch 17/1000
# 41/41 [==============================] - 3s 63ms/step - loss: 2.1929e-04 - val_loss: 0.0028
# Epoch 18/1000
# 41/41 [==============================] - 3s 64ms/step - loss: 2.2923e-04 - val_loss: 8.8403e-04
# Epoch 19/1000
# 41/41 [==============================] - 3s 66ms/step - loss: 2.0831e-04 - val_loss: 0.0016
# Epoch 20/1000
# 41/41 [==============================] - 3s 63ms/step - loss: 2.3025e-04 - val_loss: 7.3216e-04
# Epoch 21/1000
# 41/41 [==============================] - 3s 64ms/step - loss: 2.5748e-04 - val_loss: 9.7785e-04
# Epoch 22/1000
# 41/41 [==============================] - 3s 68ms/step - loss: 2.0769e-04 - val_loss: 0.0012
# Epoch 23/1000
# 41/41 [==============================] - 3s 74ms/step - loss: 2.0981e-04 - val_loss: 6.8192e-04
# Epoch 24/1000
# 41/41 [==============================] - 3s 76ms/step - loss: 2.0576e-04 - val_loss: 9.3107e-04
# Epoch 25/1000
# 41/41 [==============================] - 3s 76ms/step - loss: 2.1564e-04 - val_loss: 0.0021
# Epoch 26/1000
# 41/41 [==============================] - 3s 75ms/step - loss: 1.9579e-04 - val_loss: 0.0010
# Epoch 27/1000
# 41/41 [==============================] - 3s 76ms/step - loss: 1.7393e-04 - val_loss: 9.1335e-04
# Epoch 28/1000
# 41/41 [==============================] - 3s 74ms/step - loss: 1.9230e-04 - val_loss: 0.0031
# Epoch 29/1000
# 41/41 [==============================] - 3s 68ms/step - loss: 1.8303e-04 - val_loss: 6.3785e-04
# Epoch 30/1000
# 41/41 [==============================] - 3s 69ms/step - loss: 1.7788e-04 - val_loss: 0.0011
# Epoch 31/1000
# 41/41 [==============================] - 3s 69ms/step - loss: 1.5497e-04 - val_loss: 0.0011
# Epoch 32/1000
# 41/41 [==============================] - 3s 68ms/step - loss: 1.6560e-04 - val_loss: 0.0038
# Epoch 33/1000
# 41/41 [==============================] - 3s 72ms/step - loss: 1.9216e-04 - val_loss: 0.0028
# Epoch 34/1000
# 41/41 [==============================] - 3s 74ms/step - loss: 1.5995e-04 - val_loss: 0.0020
# Epoch 35/1000
# 41/41 [==============================] - 3s 70ms/step - loss: 1.7060e-04 - val_loss: 0.0011
# Epoch 36/1000
# 41/41 [==============================] - 3s 71ms/step - loss: 1.6379e-04 - val_loss: 9.6358e-04
# Epoch 37/1000
# 41/41 [==============================] - 3s 72ms/step - loss: 1.4301e-04 - val_loss: 0.0012
# Epoch 38/1000
# 41/41 [==============================] - 3s 71ms/step - loss: 1.3320e-04 - val_loss: 0.0011
# Epoch 39/1000
# 41/41 [==============================] - 3s 75ms/step - loss: 1.4980e-04 - val_loss: 0.0021
# Epoch 40/1000
# 41/41 [==============================] - 3s 73ms/step - loss: 1.4597e-04 - val_loss: 9.8708e-04
# Epoch 41/1000
# 41/41 [==============================] - 3s 72ms/step - loss: 1.4302e-04 - val_loss: 0.0017
# Epoch 42/1000
# 41/41 [==============================] - 3s 72ms/step - loss: 1.3981e-04 - val_loss: 9.8295e-04
# Epoch 43/1000
# 41/41 [==============================] - 3s 73ms/step - loss: 1.2702e-04 - val_loss: 0.0022
# Epoch 44/1000
# 41/41 [==============================] - 3s 69ms/step - loss: 1.2462e-04 - val_loss: 0.0034
# Epoch 45/1000
# 41/41 [==============================] - 3s 68ms/step - loss: 1.2547e-04 - val_loss: 0.0018
# Epoch 46/1000
# 41/41 [==============================] - 3s 67ms/step - loss: 1.0887e-04 - val_loss: 0.0014
# Epoch 47/1000
# 41/41 [==============================] - 3s 67ms/step - loss: 1.7066e-04 - val_loss: 9.6107e-04
# Epoch 48/1000
# 40/41 [============================>.] - ETA: 0s - loss: 1.2586e-04Restoring model weights from the end of the best epoch: 18.
# 41/41 [==============================] - 3s 65ms/step - loss: 1.2591e-04 - val_loss: 0.0034
# Epoch 48: early stopping

# %%
### prediction of x train data and check performance metrics

train_predict=model.predict(X_train)

test_predict=model.predict(X_test)
# Out:
# 41/41 [==============================] - 1s 15ms/step
# 16/16 [==============================] - 0s 14ms/step

# %%
##Transformback to original form

## Since the data was scaled we need to reverse it so we can find RMS performance matrix

train_predict=scaler.inverse_transform(train_predict)

test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

math.sqrt(mean_squared_error(y_train, train_predict))
# Out:
# 11.964612591180366

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest, test_predict))
# Out:
# 24.103088301237204

# %%
# shift train predictions for plotting

look_back=100 #time step

trainPredictPlot = numpy.empty_like(df1)

trainPredictPlot[:, :] = np.nan

trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting

testPredictPlot = numpy.empty_like(df1)

testPredictPlot[:, :] = numpy.nan

testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict

# plot baseline and predictions

plt.plot(scaler.inverse_transform(df1))

plt.plot(trainPredictPlot)

plt.plot(testPredictPlot)

plt.xlabel('Date')

plt.ylabel('Close Price')

plt.title('AAPL Stock Price Prediction')

plt.show()

# %%
#forcasting
len(test_data) # if our last date is 25th may and in order to predict 26th mays price we need 100 days data before 26th to predict it
# Out:
# 596

# %%
x_input=test_data[496:].reshape(1,-1) # hence we are taking 100 datas before that (441-100=341)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input) # convert it into a list
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.6953986529808174,
#  0.7036261015890111,
#  0.7034600693959222,
#  0.6974761999769215,
#  0.6927392323280176,
#  0.6951493971509428,
#  0.7171727374032068,
#  0.7294729557078685,
#  0.7140148050906576,
#  0.7121863755642671,
#  0.7191675450230882,
#  0.700966957656533,
#  0.7126849564040967,
#  0.7181701066231071,
#  0.7194167316728822,
#  0.7175885788668136,
#  0.7495017650605728,
#  0.7513302637670435,
#  0.7575631122955969,
#  0.7701124480699726,
#  0.7606381668717624,
#  0.7536570665930222,
#  0.7544055258834504,
#  0.7548207447263331,
#  0.7638794611812579,
#  0.7660403009942285,
#  0.7831605722244191,
#  0.7947125387788941,
#  0.7932997431758693,
#  0.7942969048555284,
#  0.794213888758984,
#  0.8009455948476889,
#  0.7960419723849723,
#  0.7922193578594243,
#  0.7882300885200637,
#  0.8089240643463297,
#  0.8245481087964684,
#  0.8198107260670819,
#  0.8281218133925439,
#  0.8375131476742902,
#  0.8266260708730553,
#  0.8361832298076489,
#  0.8160711276380784,
#  0.8170686352181398,
#  0.8200603277973587,
#  0.8318616193617888,
#  0.8451589301660293,
#  0.8456574418257785,
#  0.8269582736193938,
#  0.8072616670130284,
#  0.8025246993641243,
#  0.8043527829901124,
#  0.7947125387788941,
#  0.7923024431360493,
#  0.787315942936949,
#  0.7812489190612429,
#  0.7269797056083184,
#  0.7021306357898441,
#  0.6930714350743561,
#  0.6922406514881881,
#  0.7050391047322772,
#  0.6968114485838421,
#  0.6936342150288467,
#  0.6892863161524142,
#  0.6898715796330522,
#  0.695139020138875,
#  0.6875304565304197,
#  0.6693861817493537,
#  0.6708910560394625,
#  0.6989854326120987,
#  0.6957244911597542,
#  0.7046709975241833,
#  0.7016609030435638,
#  0.710189630902133,
#  0.7203070101282406,
#  0.7325980274822018,
#  0.7469796668674733,
#  0.7535852576695112,
#  0.7530835637260612,
#  0.7489865810014343,
#  0.7372805504077887,
#  0.7310930840120128,
#  0.7327653049167391,
#  0.7387019935208703,
#  0.7420465045104028,
#  0.7412938944151475,
#  0.7472305830192788,
#  0.7403742836056768,
#  0.7279156429167759,
#  0.728919030803676,
#  0.7262436295522914,
#  0.7296717100790119,
#  0.7111093800717646,
#  0.7091863121953136,
#  0.7159590420717276,
#  0.7129488784110277,
#  0.7175474858990242,
#  0.6949720194246597,
#  0.6836004053399274,
#  0.6965605324320367]

# %%
from numpy import array

 

lst_output=[]

n_steps=100

i=0

while(i<30):

    

    if(len(temp_input)>100):

        #print(temp_input)

        x_input=np.array(temp_input[1:]) # one position is shifted to the right

        print("{} day input {}".format(i,x_input))

        x_input=x_input.reshape(1,-1)

        x_input = x_input.reshape((1, n_steps, 1))

        #print(x_input)

        yhat = model.predict(x_input, verbose=0)

        print("{} day output {}".format(i,yhat))

        temp_input.extend(yhat[0].tolist())

        temp_input=temp_input[1:]

        #print(temp_input)

        lst_output.extend(yhat.tolist())

        i=i+1

    else:

        x_input = x_input.reshape((1, n_steps,1)) # we reshape the data before we pass it to our lstm model

        yhat = model.predict(x_input, verbose=0) #

        print(yhat[0]) # output

        temp_input.extend(yhat[0].tolist())

        print(len(temp_input))

        lst_output.extend(yhat.tolist())
        i=i+1 # the else statement is then terminated and ONLY the IF statement will be running


print(lst_output)
# Out:
# [0.6969873]
# 101
# 1 day input [0.7036261  0.70346007 0.6974762  0.69273923 0.6951494  0.71717274
#  0.72947296 0.71401481 0.71218638 0.71916755 0.70096696 0.71268496
#  0.71817011 0.71941673 0.71758858 0.74950177 0.75133026 0.75756311
#  0.77011245 0.76063817 0.75365707 0.75440553 0.75482074 0.76387946
#  0.7660403  0.78316057 0.79471254 0.79329974 0.7942969  0.79421389
#  0.80094559 0.79604197 0.79221936 0.78823009 0.80892406 0.82454811
#  0.81981073 0.82812181 0.83751315 0.82662607 0.83618323 0.81607113
#  0.81706864 0.82006033 0.83186162 0.84515893 0.84565744 0.82695827
#  0.80726167 0.8025247  0.80435278 0.79471254 0.79230244 0.78731594
#  0.78124892 0.72697971 0.70213064 0.69307144 0.69224065 0.7050391
#  0.69681145 0.69363422 0.68928632 0.68987158 0.69513902 0.68753046
#  0.66938618 0.67089106 0.69898543 0.69572449 0.704671   0.7016609
#  0.71018963 0.72030701 0.73259803 0.74697967 0.75358526 0.75308356
#  0.74898658 0.73728055 0.73109308 0.7327653  0.73870199 0.7420465
#  0.74129389 0.74723058 0.74037428 0.72791564 0.72891903 0.72624363
#  0.72967171 0.71110938 0.70918631 0.71595904 0.71294888 0.71754749
#  0.69497202 0.68360041 0.69656053 0.69698727]
# 1 day output [[0.6920927]]
# 2 day input [0.70346007 0.6974762  0.69273923 0.6951494  0.71717274 0.72947296
#  0.71401481 0.71218638 0.71916755 0.70096696 0.71268496 0.71817011
#  0.71941673 0.71758858 0.74950177 0.75133026 0.75756311 0.77011245
#  0.76063817 0.75365707 0.75440553 0.75482074 0.76387946 0.7660403
#  0.78316057 0.79471254 0.79329974 0.7942969  0.79421389 0.80094559
#  0.79604197 0.79221936 0.78823009 0.80892406 0.82454811 0.81981073
#  0.82812181 0.83751315 0.82662607 0.83618323 0.81607113 0.81706864
#  0.82006033 0.83186162 0.84515893 0.84565744 0.82695827 0.80726167
#  0.8025247  0.80435278 0.79471254 0.79230244 0.78731594 0.78124892
#  0.72697971 0.70213064 0.69307144 0.69224065 0.7050391  0.69681145
#  0.69363422 0.68928632 0.68987158 0.69513902 0.68753046 0.66938618
#  0.67089106 0.69898543 0.69572449 0.704671   0.7016609  0.71018963
#  0.79471254 0.79230244 0.78731594 0.78124892 0.72697971 0.70213064
#  0.69307144 0.69224065 0.7050391  0.69681145 0.69363422 0.68928632
#  0.68987158 0.69513902 0.68753046 0.66938618 0.67089106 0.69898543
#  0.69572449 0.704671   0.7016609  0.71018963 0.72030701 0.73259803
#  0.74697967 0.75358526 0.75308356 0.74898658 0.73728055 0.73109308
#  0.7327653  0.73870199 0.7420465  0.74129389 0.74723058 0.74037428
#  0.72791564 0.72891903 0.72624363 0.72967171 0.71110938 0.70918631
#  0.71595904 0.71294888 0.71754749 0.69497202 0.68360041 0.69656053
#  0.69698727 0.69209272 0.68716425 0.68231958 0.67769825 0.67331296
#  0.66897291 0.66427785 0.65939313 0.65474427 0.65012747 0.64551103
#  0.6412847  0.63702476 0.6328513  0.62888521 0.62506741 0.62089604
#  0.61674941 0.61249906 0.60809678 0.60389155 0.59990376 0.59607482
#  0.59241605 0.58884096 0.58539057 0.5818162 ]
# 28 day output [[0.57821786]]
# 29 day input [0.7942969  0.79421389 0.80094559 0.79604197 0.79221936 0.78823009
#  0.80892406 0.82454811 0.81981073 0.82812181 0.83751315 0.82662607
#  0.83618323 0.81607113 0.81706864 0.82006033 0.83186162 0.84515893
#  0.84565744 0.82695827 0.80726167 0.8025247  0.80435278 0.79471254
#  0.79230244 0.78731594 0.78124892 0.72697971 0.70213064 0.69307144
#  0.69224065 0.7050391  0.69681145 0.69363422 0.68928632 0.68987158
#  0.69513902 0.68753046 0.66938618 0.67089106 0.69898543 0.69572449
#  0.704671   0.7016609  0.71018963 0.72030701 0.73259803 0.74697967
#  0.75358526 0.75308356 0.74898658 0.73728055 0.73109308 0.7327653
#  0.73870199 0.7420465  0.74129389 0.74723058 0.74037428 0.72791564
#  0.72891903 0.72624363 0.72967171 0.71110938 0.70918631 0.71595904
#  0.71294888 0.71754749 0.69497202 0.68360041 0.69656053 0.69698727
#  0.69209272 0.68716425 0.68231958 0.67769825 0.67331296 0.66897291
#  0.66427785 0.65939313 0.65474427 0.65012747 0.64551103 0.6412847
#  0.63702476 0.6328513  0.62888521 0.62506741 0.62089604 0.61674941
#  0.61249906 0.60809678 0.60389155 0.59990376 0.59607482 0.59241605
#  0.58884096 0.58539057 0.5818162  0.57821786]
# 29 day output [[0.5747544]]
# [[0.6969872713088989], [0.6920927166938782], [0.6871642470359802], [0.6823195815086365], [0.6776982545852661], [0.6733129620552063], [0.668972909450531], [0.6642778515815735], [0.6593931317329407], [0.6547442674636841], [0.6501274704933167], [0.6455110311508179], [0.641284704208374], [0.6370247602462769], [0.6328513026237488], [0.6288852095603943], [0.625067412853241], [0.62089604139328], [0.6167494058609009], [0.6124990582466125], [0.6080967783927917], [0.6038915514945984], [0.5999037623405457], [0.5960748195648193], [0.5924160480499268], [0.5888409614562988], [0.585390567779541], [0.5818161964416504], [0.5782178640365601], [0.5747544169425964]]

# %%
day_new=np.arange(1,101) # from tests data we have taken previous 100 days

# %%
day_pred=np.arange(101,131) # we are taking the next 30 days

# %%
len(df1) #1258-100=1158
# Out:
# 1986

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1886:])) # 1258-100=1258
plt.plot(day_pred,scaler.inverse_transform(lst_output))
plt.xlabel('Date')

plt.ylabel('Close Price')
plt.title('AAPL Stock Price Prediction')

plt.show()

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.xlabel('Date')
plt.ylabel('Close Price')
plt
735852003097534], [2.7634387016296387], [2.7037196159362797], [2.707358121871948], [2.6658272743225098], [2.6788620948791504], [2.7637410163879395], [2.693110704421997], [2.5857980251312256], [2.519409418106079], [2.68674373626709], [2.8095157146453857], [2.920770168304444], [2.9080371856689453], [2.892577648162842], [3.021109342575073], [3.07749342918396], [3.0805256366729736], [3.079615592956543], [3.263622760772705], [3.2284576892852783], [3.228154182434082], [3.330617666244507], [3.239068031311035], [3.167527198791504], [3.1866250038146973], [3.2948460578918457], [3.416709423065185], [3.5161406993865967], [3.590713024139404], [3.4861290454864506], [3.526143312454224], [3.6246643066406254], [3.6443676948547354], [3.5864684581756596], [3.5661582946777344], [3.6816539764404297], [3.741374015808106], [3.6528570652008057], [3.6910524368286133], [3.68347430229187], [3.801395893096924], [3.7559247016906734], [3.7810869216918954], [3.7559247016906734], [3.793514013290405], [3.814431190490722], [3.8571739196777344], [4.0035905838012695], [4.022994518280029], [4.016626358032227], [3.912346124649048 ...

# %%
print(lst_output) # scaled values of predicted prices
print(scaler.inverse_transform(lst_output)) # the predicted prices for the 30 days
# Out:
# [[0.6969872713088989], [0.6920927166938782], [0.6871642470359802], [0.6823195815086365], [0.6776982545852661], [0.6733129620552063], [0.668972909450531], [0.6642778515815735], [0.6593931317329407], [0.6547442674636841], [0.6501274704933167], [0.6455110311508179], [0.641284704208374], [0.6370247602462769], [0.6328513026237488], [0.6288852095603943], [0.625067412853241], [0.62089604139328], [0.6167494058609009], [0.6124990582466125], [0.6080967783927917], [0.6038915514945984], [0.5999037623405457], [0.5960748195648193], [0.5924160480499268], [0.5888409614562988], [0.585390567779541], [0.5818161964416504], [0.5782178640365601], [0.5747544169425964]]
# [[21.58704857]
#  [21.4521019 ]
#  [21.31622015]
#  [21.18264896]
#  [21.05523538]
#  [20.93432945]
#  [20.81467082]
#  [20.68522443]
#  [20.5505489 ]
#  [20.4223761 ]
#  [20.29508741]
#  [20.16780859]
#  [20.05128547]
#  [19.9338355 ]
#  [19.81877003]
#  [19.70942175]
#  [19.60416213]
#  [19.48915417]
#  [19.37482821]
#  [19.25764282]
#  [19.13626854]
#  [19.02032716]
#  [18.91038071]
#  [18.80481378]
#  [18.7039386 ]
#  [18.60537068]
#  [18.51024065]
#  [18.41169245]
#  [18.31248362]
#  [18.21699369]]

# %%
forcasted_price=(scaler.inverse_transform(lst_output))

# %%
forcasted_price
# Out:
# array([[21.58704857],
#        [21.4521019 ],
#        [21.31622015],
#        [21.18264896],
#        [21.05523538],
#        [20.93432945],
#        [20.81467082],
#        [20.68522443],
#        [20.5505489 ],
#        [20.4223761 ],
#        [20.29508741],
#        [20.16780859],
#        [20.05128547],
#        [19.9338355 ],
#        [19.81877003],
#        [19.70942175],
#        [19.60416213],
#        [19.48915417],
#        [19.37482821],
#        [19.25764282],
#        [19.13626854],
#        [19.02032716],
#        [18.91038071],
#        [18.80481378],
#        [18.7039386 ],
#        [18.60537068],
#        [18.51024065],
#        [18.41169245],
#        [18.31248362],
#        [18.21699369]])
